# %%
import pandas as pd

# %%
# dataset #1: tweets about 2016 presidential debates

# %%
df1 = pd.read_csv('Sentiment.csv')

# %%
df1.head()
# Out:
#    id               candidate  candidate_confidence relevant_yn  \
# 0   1  No candidate mentioned                   1.0         yes
# 1   2            Scott Walker                   1.0         yes
# 2   3  No candidate mentioned                   1.0         yes
# 3   4  No candidate mentioned                   1.0         yes
# 4   5            Donald Trump                   1.0         yes
#
#    relevant_yn_confidence sentiment  sentiment_confidence     subject_matter  \
# 0                     1.0   Neutral                0.6578  None of the above
# 1                     1.0  Positive                0.6333  None of the above
# 2                     1.0   Neutral                0.6629  None of the above
# 3                     1.0  Positive                1.0000  None of the above
# 4                     1.0  Positive                0.7045  None of the above
#
#    subject_matter_confidence candidate_gold  ... relevant_yn_gold  \
# ...

# %%
df1.shape
# Out:
# (13871, 21)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13871 entries, 0 to 13870
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         13871 non-null  int64
#  1   candidate                  13775 non-null  object
#  2   candidate_confidence       13871 non-null  float64
#  3   relevant_yn                13871 non-null  object
#  4   relevant_yn_confidence     13871 non-null  float64
#  5   sentiment                  13871 non-null  object
#  6   sentiment_confidence       13871 non-null  float64
#  7   subject_matter             13545 non-null  object
#  8   subject_matter_confidence  13871 non-null  float64
#  9   candidate_gold             28 non-null     object
#  10  name                       13871 non-null  object
#  11  relevant_yn_gold           32 non-null     object
#  12  retweet_count              13871 non-null  int64
# ...

# %%
df1.describe()
# Out:
#                  id  candidate_confidence  relevant_yn_confidence  \
# count  13871.000000          13871.000000            13871.000000
# mean    6936.000000              0.855689                0.927304
# std     4004.357127              0.241388                0.141696
# min        1.000000              0.222200                0.333300
# 25%     3468.500000              0.674200                1.000000
# 50%     6936.000000              1.000000                1.000000
# 75%    10403.500000              1.000000                1.000000
# max    13871.000000              1.000000                1.000000
#
#        sentiment_confidence  subject_matter_confidence  retweet_count  \
# count          13871.000000               13871.000000   13871.000000
# mean               0.756936                   0.782801      45.803331
# std                0.217682                   0.258215     153.981724
# min                0.186000                   0.222200       0.000000
# ...

# %%
# dataset 2: tweets right before 2020 election, used VADER

# %%
df2 = pd.read_csv('tweets_election.csv')

# %%
df2.head()
# Out:
#    Unnamed: 0  geo                                               text  \
# 0           3  NaN   After the confrontation that cost Walter Wall...
# 1           6  NaN   "COVID-19 is still raging. Trump is still lyi...
# 2          11  NaN   Donald Trump Jr.: "Why aren't they talking ab...
# 3          15  NaN  Let’s not forget who created these problems. T...
# 4          16  NaN   There is no greater supporter of Donald Trump...
#
#               user                   location       Subject          state
# 0    wheresestela1                 New Jersey  Donald Trump     New Jersey
# 1  TheFemaleYungin  The Wrong Address, Texas   Donald Trump          Texas
# 2  KathrynTomashu1           Northborough, MA  Donald Trump  Massachusetts
# 3         ajserino            New Jersey, USA  Donald Trump     New Jersey
# 4     SpeakBravely     Twin Cities, Minnesota  Donald Trump      Minnesota

# %%
# dataset 3:

# %%
df3 = pd.read_csv('hate_Sp_train.csv')

# %%
df3.head()
# Out:
#    id  label                                              tweet
# 0   1      0   @user when a father is dysfunctional and is s...
# 1   2      0  @user @user thanks for #lyft credit i can't us...
# 2   3      0                                bihday your majesty
# 3   4      0  #model   i love u take with u all the time in ...
# 4   5      0             factsguide: society now    #motivation
